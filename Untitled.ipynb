# %%
import feather

# %%
path="/Users/prabha/GitHub/Collage.feather"

# %%
data=feather.read_dataframe(path)

# %%
data.shape
# Out:
# (777, 19)

# %%
data.head(5)
# Out:
#   Private    Apps  Accept  Enroll  Top10perc  Top25perc  F.Undergrad  \
# 0     Yes  1660.0  1232.0   721.0       23.0       52.0       2885.0
# 1     Yes  2186.0  1924.0   512.0       16.0       29.0       2683.0
# 2     Yes  1428.0  1097.0   336.0       22.0       50.0       1036.0
# 3     Yes   417.0   349.0   137.0       60.0       89.0        510.0
# 4     Yes   193.0   146.0    55.0       16.0       44.0        249.0
#
#    P.Undergrad  Outstate  Room.Board  Books  Personal   PhD  Terminal  \
# 0        537.0    7440.0      3300.0  450.0    2200.0  70.0      78.0
# 1       1227.0   12280.0      6450.0  750.0    1500.0  29.0      30.0
# 2         99.0   11250.0      3750.0  400.0    1165.0  53.0      66.0
# 3         63.0   12960.0      5450.0  450.0     875.0  92.0      97.0
# 4        869.0    7560.0      4120.0  800.0    1500.0  76.0      72.0
#
#    S.F.Ratio  perc.alumni   Expend  Grad.Rate                          Name
# ...

# %%
from ggplot import *

# %%
ggplot(data,aes(x='Elite',y='Outstate'))+geom_boxplot()
# Out:
# <ggplot: (-9223372036572048352)>

# %%
data['Elite']=data.Top10perc>50

# %%
import numpy

# %%
plot(numpy.random.normal(10,1,20))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-6238d69d09a6> in <module>()
# ----> 1 plot(numpy.random.normal(10,1,20))
#
# NameError: name 'plot' is not defined

# %%
x=numpy.random.uniform(0,1000,100)

# %%
y=2+(3*x)+numpy.random.normal(0,1000,100)

# %%
from ggplot import *

# %%
import pandas as pd

# %%
data=pd.DataFrame({'x1':x,'y1':y})

# %%
ggplot(data,aes(x='x1',y='y1'))+geom_point()
# Out:
# <ggplot: (291624533)>
